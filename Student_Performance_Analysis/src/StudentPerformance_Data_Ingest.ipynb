# %% [markdown]
# # **Stage 1 - Ingest**
# # **Read raw CSV into a pandas DataFrame.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Load raw data of student performance
df = pd.read_csv("/content/drive/MyDrive/Student_Performance_Analysis/Data_Raw/Students_Performance.csv")

# %%
# Save ingested data for Stage 2

df.to_csv("/content/drive/MyDrive/Student_Performance_Analysis/Data_Clean/std_Performance_ingested.csv", index=False)
print("Stage 1 complete — data saved!")
# Out:
# Stage 1 complete — data saved!
