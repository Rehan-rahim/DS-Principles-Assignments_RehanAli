# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = 'drive/MyDrive/Frailty_Grip_Strength_Analysis'

# %%
import os
os.listdir(folder_path)
# Out:
# ['Data_Raw']

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Frailty_Grip_Strength_Analysis/Data_Raw/Raw_Frailty_Data.csv'

df = pd.read_csv(file_path)

# %%
df
# Out:
#    Height  Weight  Age  Grip strength Frailty
# 0    65.8     112   30             30       N
# 1    71.5     136   19             31       N
# 2    69.4     153   45             29       N
# 3    68.2     142   22             28       Y
# 4    67.8     144   29             24       Y
# 5    68.7     123   50             26       N
# 6    69.8     141   51             22       Y
# 7    70.1     136   23             20       Y
# 8    67.9     112   17             19       N
# 9    66.8     120   39             31       N
